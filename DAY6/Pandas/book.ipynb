# %% [markdown]
# ### CODES OF WHATEVER I READ IN THE BOOK

# %% [markdown]
# ### BASIC IMPORTS

# %%
import numpy as np 
import pandas as pd

# %%
### The Pandas Series object 
data=pd.Series([0.25,0.5,0.75,1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
### changing the name of the index value

data=pd.Series([0.25,0.5,0.75,1.0,1.25],index=['a','b','c','d','e'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# e    1.25
# dtype: float64

# %%
### lets try series with the dictonary 
area_dict={'california':420394,
           'Japan':438204,
           'USA':48320,
           'hongkong':74209}
area=pd.Series(area_dict)
area
# Out:
# california    420394
# Japan         438204
# USA            48320
# hongkong       74209
# dtype: int64

# %%
# we can use two dimensional dict 
pop=list(map(int,input().split()))
area_2D= pd.DataFrame({'population':pop,'area':area})
area_2D
# Out:
#             population    area
# california     3748294  420394
# Japan          6493264  438204
# USA            7349284   48320
# hongkong       4732947   74209

# %%
area_2D.index
# Out:
# Index(['california', 'Japan', 'USA', 'hongkong'], dtype='str')

# %%
area_2D.columns
# Out:
# Index(['population', 'area'], dtype='str')
