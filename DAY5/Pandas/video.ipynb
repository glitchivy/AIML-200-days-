# %% [markdown]
# # CODES FROM VIDEO LECS

# %% [markdown]
# Installing pandas

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\tanis\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# importing pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
# 1. create Dataframe
df=pd.DataFrame([11,22,3],columns=['numbers'])
print(df)
# Out:
#    numbers
# 0       11
# 1       22
# 2        3

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
data={
    'Name':['Madhav','Purava','chinki'],
    'Age':[18,22,20],
    'Salary':[10000,200000,3000]
}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#      Name  Age  Salary
# 0  Madhav   18   10000
# 1  Purava   22  200000
# 2  chinki   20    3000

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %% [markdown]
# ### 2. basic dataframe Understanding

# %%
df.head(2) # prints top rows
# Out:
#      Name  Age  Salary
# 0  Madhav   18   10000
# 1  Purava   22  200000

# %%
df.tail(2) # prints bottom 2 rows
# Out:
#      Name  Age  Salary
# 1  Purava   22  200000
# 2  chinki   20    3000

# %%
df.shape # 3 rows and 3 columns
# Out:
# (3, 3)

# %%
df.columns # represents columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='str')

# %%
df=df.rename(columns={'Salary':"Monthly_salary"})
print(df)
# or we can use inplace method basically it changes in the main column rather than changing temprory

df.rename(columns={'Name':'Employee'},inplace=True)
# Out:
#      Name  Age  Monthly_salary
# 0  Madhav   18           10000
# 1  Purava   22          200000
# 2  chinki   20            3000

# %%
df
# Out:
#   Employee  Age  Monthly_salary
# 0   Madhav   18           10000
# 1   Purava   22          200000
# 2   chinki   20            3000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Employee        3 non-null      str
#  1   Age             3 non-null      int64
#  2   Monthly_salary  3 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 204.0 bytes

# %%
df.describe()
# Out:
#         Age  Monthly_salary
# count   3.0        3.000000
# mean   20.0    71000.000000
# std     2.0   111772.089539
# min    18.0     3000.000000
# 25%    19.0     6500.000000
# 50%    20.0    10000.000000
# 75%    21.0   105000.000000
# max    22.0   200000.000000

# %% [markdown]
# ### 3. Save and load data from csv

# %%
# lets save the data first 
df.to_csv('Test_data.csv',index=False) #exports data

# %%
load_df=pd.read_csv("Test_data.csv")
load_df # imports data
# Out:
#   Employee  Age  Monthly_salary
# 0   Madhav   18           10000
# 1   Purava   22          200000
# 2   chinki   20            3000

# %%
df # normal data
# Out:
#   Employee  Age  Monthly_salary
# 0   Madhav   18           10000
# 1   Purava   22          200000
# 2   chinki   20            3000

# %% [markdown]
# ### 4. Rows and columns- Selection

# %%
df[['Employee','Monthly_salary']] #select columns
# Out:
#   Employee  Monthly_salary
# 0   Madhav           10000
# 1   Purava          200000
# 2   chinki            3000

# %%
# select rows 
#loc - index name based
df.loc[df.Employee=='Purava'] # for one condition
df.loc[(df.Employee=='Madhav') & (df.Monthly_salary>=100)]
#for mulltiple condition
# Out:
#   Employee  Age  Monthly_salary
# 0   Madhav   18           10000

# %%
#iloc - gives index based values 
df.iloc[0]
df.iloc[0:2] #[start:stop:step]
# Out:
#   Employee  Age  Monthly_salary
# 0   Madhav   18           10000
# 1   Purava   22          200000

# %%
 # filter the dataframe

df_age=df[(df['Age']>19) & (df['Monthly_salary']>=1000)]

# %%
df_age
# Out:
#   Employee  Age  Monthly_salary
# 1   Purava   22          200000
# 2   chinki   20            3000

# %%
# where method 
df.where(df['Age']>=19, other="Not eligible")
# Out:
#        Employee           Age Monthly_salary
# 0  Not eligible  Not eligible   Not eligible
# 1        Purava            22         200000
# 2        chinki            20           3000

# %% [markdown]
# ### rows and columns - Operations(add,update,delete)

# %%
df
# Out:
#   Employee  Age  Monthly_salary
# 0   Madhav   18           10000
# 1   Purava   22          200000
# 2   chinki   20            3000

# %%
# add new column 
df['Team']=['HR','CEO','Tester']
df
# Out:
#   Employee  Age  Monthly_salary    Team
# 0   Madhav   18           10000      HR
# 1   Purava   22          200000     CEO
# 2   chinki   20            3000  Tester

# %%
# other method for column 
df['Bonus']=df['Monthly_salary']*0.2
df
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus
# 0   Madhav   18           10000      HR   2000.0
# 1   Purava   22          200000     CEO  40000.0
# 2   chinki   20            3000  Tester    600.0

# %%
# add a new row 
df.loc[len(df)]=['piakchu',22,30000,'VIBE CODER',6000]

# %%
len(df)
# Out:
# 4

# %%
# updating the values 
df.loc[0,'Monthly_salary']=50000
df
# Out:
#   Employee  Age  Monthly_salary        Team    Bonus
# 0   Madhav   18           50000          HR   2000.0
# 1   Purava   22          200000         CEO  40000.0
# 2   chinki   20            3000      Tester    600.0
# 3  piakchu   22           30000  VIBE CODER   6000.0

# %%
# other method to update the values 
df.loc[df.Employee=='Madhav','Monthly_Salary']=60000

# %%
#deleting values
# deleting rows 
df=df.drop(df[df.Employee=='piakchu'].index)
df
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus  Monthly_Salary
# 0   Madhav   18           50000      HR   2000.0         60000.0
# 1   Purava   22          200000     CEO  40000.0             NaN
# 2   chinki   20            3000  Tester    600.0             NaN

# %%
# deleting columns 
df=df.drop('Monthly_Salary',axis=1)

# %%
df
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus
# 0   Madhav   18           50000      HR   2000.0
# 1   Purava   22          200000     CEO  40000.0
# 2   chinki   20            3000  Tester    600.0

# %%
# sorting of the values
df.sort_values('Monthly_salary',ascending=False)
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus
# 1   Purava   22          200000     CEO  40000.0
# 0   Madhav   18           50000      HR   2000.0
# 2   chinki   20            3000  Tester    600.0

# %% [markdown]
# ### WORKING WITH DATE VALUES

# %%
df['DOJ']=['2024-01-01','2024-01-15','2024-03-28']
df
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus         DOJ
# 0   Madhav   18           50000      HR   2000.0  2024-01-01
# 1   Purava   22          200000     CEO  40000.0  2024-01-15
# 2   chinki   20            3000  Tester    600.0  2024-03-28

# %%
df['DOJ'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[us]')

# %%
df1 = df

# %%
df1
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus        DOJ
# 0   Madhav   18           50000      HR   2000.0 2024-01-01
# 1   Purava   22          200000     CEO  40000.0 2024-01-15
# 2   chinki   20            3000  Tester    600.0 2024-03-28

# %%
df1['DOJ2']=['15-01-2025','01-01-2025','28-03-2025']
df1
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus        DOJ        DOJ2
# 0   Madhav   18           50000      HR   2000.0 2024-01-01  15-01-2025
# 1   Purava   22          200000     CEO  40000.0 2024-01-15  01-01-2025
# 2   chinki   20            3000  Tester    600.0 2024-03-28  28-03-2025

# %%
df1['DOJ2'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df1['DOJ2']=pd.to_datetime(df1['DOJ2'],format='%d-%m-%Y')

# %%
df1
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus        DOJ       DOJ2
# 0   Madhav   18           50000      HR   2000.0 2024-01-01 2025-01-15
# 1   Purava   22          200000     CEO  40000.0 2024-01-15 2025-01-01
# 2   chinki   20            3000  Tester    600.0 2024-03-28 2025-03-28

# %%
df1['DOJ2'].dtype
# Out:
# dtype('<M8[us]')

# %%
df.drop('DOJ2',axis=1,inplace=True)
df
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus        DOJ
# 0   Madhav   18           50000      HR   2000.0 2024-01-01
# 1   Purava   22          200000     CEO  40000.0 2024-01-15
# 2   chinki   20            3000  Tester    600.0 2024-03-28

# %%
# extract year,month,week,day 
df['DOJ'].dt.year
# Out:
# 0    2024
# 1    2024
# 2    2024
# Name: DOJ, dtype: int32

# %%
df['DOJ'].dt.month
# Out:
# 0    1
# 1    1
# 2    3
# Name: DOJ, dtype: int32

# %%
df['DOJ'].dt.day
# Out:
# 0     1
# 1    15
# 2    28
# Name: DOJ, dtype: int32

# %%
df['DOJ']+pd.Timedelta(days=90)
# Out:
# 0   2024-03-31
# 1   2024-04-14
# 2   2024-06-26
# Name: DOJ, dtype: datetime64[us]

# %%
df.isnull()
# Out:
#    Employee    Age  Monthly_salary   Team  Bonus    DOJ
# 0     False  False           False  False  False  False
# 1     False  False           False  False  False  False
# 2     False  False           False  False  False  False

# %%
import numpy as np

# %%
df.loc[df.Employee=='Madhav','Monthly_salary']=np.nan

# %%
df
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus        DOJ
# 0   Madhav   18             NaN      HR   2000.0 2024-01-01
# 1   Purava   22        200000.0     CEO  40000.0 2024-01-15
# 2   chinki   20          3000.0  Tester    600.0 2024-03-28

# %%
df.isnull().sum()
# Out:
# Employee          0
# Age               0
# Monthly_salary    1
# Team              0
# Bonus             0
# DOJ               0
# dtype: int64

# %%
df.fillna(0)
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus        DOJ
# 0   Madhav   18             0.0      HR   2000.0 2024-01-01
# 1   Purava   22        200000.0     CEO  40000.0 2024-01-15
# 2   chinki   20          3000.0  Tester    600.0 2024-03-28

# %% [markdown]
# ### 9. aggreate function and group BY

# %%
df['Team'].value_counts()
# Out:
# Team
# HR        1
# CEO       1
# Tester    1
# Name: count, dtype: int64

# %%
df
# Out:
#   Employee  Age  Monthly_salary    Team    Bonus        DOJ
# 0   Madhav   18             NaN      HR   2000.0 2024-01-01
# 1   Purava   22        200000.0     CEO  40000.0 2024-01-15
# 2   chinki   20          3000.0  Tester    600.0 2024-03-28

# %%
df.groupby('Age')['Monthly_salary'].sum()
# Out:
# Age
# 18         0.0
# 20      3000.0
# 22    200000.0
# Name: Monthly_salary, dtype: float64
