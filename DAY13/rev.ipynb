# %%
import pandas as pd

# Creating a DataFrame with information about students and schools
data = {
  "Student Name": ["James", "Anna", "Laura", "Peter"],
  "Grade": [9, 10, 8, 10],
  "School": ["Riverdale High", "Sunnydale High", "Riverdale High", "Westview High"]
}

df = pd.DataFrame(data)
df.set_index("Student Name", inplace=True) # Setting 'Student Name' as the index
# TODO: rename the `School` column
df.rename(columns={'School':'Institution'},inplace=True)
print(df)
# Out:
#               Grade     Institution
# Student Name
# James             9  Riverdale High
# Anna             10  Sunnydale High
# Laura             8  Riverdale High
# Peter            10   Westview High

# %% [markdown]
# ###  Data Filtering

# %%
import pandas as pd
data={"Name":['alice','bob','charley'],
      "Age":[11,13,13],
      "grade":[3,7,5]}

df=pd.DataFrame(data)

grades_student=df[df['grade']>=5]
print(grades_student)
# Out:
#       Name  Age  grade
# 1      bob   13      7
# 2  charley   13      5

# %% [markdown]
# ### Boolean Masking

# %%
import pandas as pd
data=[1,2,3,4,5,6,7,7,8,9]
df=pd.Series(data)
mask=df==7
value=df[mask]
print(value)
# Out:
# 6    7
# 7    7
# dtype: int64

# %% [markdown]
# ### Advanced Data Filtering

# %%
import pandas as pd
grade={"name":["casjk",'dywuo','dguieas'],
       "age":[11,35,22],
       "grade": [12,54,31]}
df=pd.DataFrame(grade)

mask_grade=df[(df['grade']>30) & (df['grade']<50)]
print(mask_grade)
# Out:
#       name  age  grade
# 2  dguieas   22     31

# %%
middle_school_students = df[df['grade'].isin([6, 7])]

print(middle_school_students)
# Out:
# Empty DataFrame
# Columns: [name, age, grade]
# Index: []

# %%
# Data of students in a school
school_data = {'student_id': [101, 102, 103, 104, 105],
               'name': ['Liam', 'Olivia', 'Noah', 'Emma', 'James'],
               'grade': [5, 6, 5, 6, 6]}

school_df = pd.DataFrame(school_data)

# Filter 6th grade students using a boolean mask
sixth_grade_students = school_df[school_df['grade'] == 6]
print(sixth_grade_students)
# Out:
#    student_id    name  grade
# 1         102  Olivia      6
# 3         104    Emma      6
# 4         105   James      6

# %%
import pandas as pd

# Example DataFrame simulating a school's student records
student_records = pd.DataFrame({
    'StudentID': [101, 102, 103, 104, 105],
    'Score': ['A', 'B', 'C', 'B', 'A'],
    'Grade': [5, 5, 6, 5, 6]
})

# Filter the DataFrame to show students in 6th grade with Score A
sixth_grade_A = student_records[(student_records['Grade'] == 6) & (student_records['Score'] == 'A')]
print(sixth_grade_A)
# Out:
#    StudentID Score  Grade
# 4        105     A      6

# %%
import pandas as pd

# Data about schools
school_data = {
    'name': ['Greenfield Elementary', 'Sunnydale High', 'Riverside Elementary 1', 'Riverside Elementary 2'],
    'type': ['Elementary', 'High', 'Elementary', 'Elementary'],
    'city': ['Greenfield', 'Sunnydale', 'Riverside', 'Riverside']
}

schools_df = pd.DataFrame(school_data)

# Filter schools of type 'Elementary'
elementary_schools = schools_df[(schools_df['type'] == 'Elementary') & (schools_df['city'] == 'Riverside')]
print(elementary_schools)
# Out:
#                      name        type       city
# 2  Riverside Elementary 1  Elementary  Riverside
# 3  Riverside Elementary 2  Elementary  Riverside

# %%
import pandas as pd

# Data of students
data = {
    'name': ['Alice', 'Bob', 'Charlie', 'Mary', 'John'],
    'age': [12, 13, 14, 15, 12],
    'grade_level': [10, 7, 8, 9, 10]
}

students_df = pd.DataFrame(data)

# TODO: Filter students who are in 8th or 10th grade
filtered_students = students_df[(students_df['grade_level']==8) | (students_df['grade_level']==10)]

print(filtered_students)
# Out:
#       name  age  grade_level
# 0    Alice   12           10
# 2  Charlie   14            8
# 4     John   12           10

# %%
import pandas as pd

# Data of students
data = {
    'name': ['Alice', 'Bob', 'Charlie', 'Mary', 'John'],
    'age': [12, 13, 14, 15, 12],
    'grade_level': [10, 7, 8, 9, 10]
}

students_df = pd.DataFrame(data)

# TODO: Filter students who are in 8th or 10th grade
filtered_students =students_df[students_df['grade_level'].isin([8,10])]

print(filtered_students)
# Out:
#       name  age  grade_level
# 0    Alice   12           10
# 2  Charlie   14            8
# 4     John   12           10

# %%
# Sample data from the School and Education System
data = {
    'student_id': [1, 2, 3, 4, 5],
    'test_score': [89, 92, 78, 90, 85],
    'grade_level': [10, 10, 9, 10, 9]
}

students_df = pd.DataFrame(data)

# TODO: Use a filter to find students in the 10th grade who have a test score higher than 90.
high_achieving_sophomores=students_df[(students_df['grade_level']==10) & (students_df['test_score']>90)]
print(high_achieving_sophomores)
# Out:
#    student_id  test_score  grade_level
# 1           2          92           10

# %%
import pandas as pd

# TODO: Create a dictionary with school data including school names, types, and grades
data={'school':['Greenhill', 'Sunnyvale', 'Riverside', 'Oakwood'],
       'type':['Public', 'Private', 'Public', 'Charter'],
       'grades':[8,10,9,12]}

# TODO: Convert the dictionary to a DataFrame

df=pd.DataFrame(data)

# TODO: Filter the DataFrame to include only Charter type schools
school=df[df['type']=='Charter']
# TODO: Print the DataFrame with filtered Charter type schools
print(school)
# Out:
#     school     type  grades
# 3  Oakwood  Charter      12

# %%
import pandas as pd

# Creating DataFrame
data =  {'Name': ['Tommy', 'Rex', 'Bella', 'Charlie', 'Lucy', 'Cooper'],
         'Type': ['Dog', 'Dog', 'Cat', 'Cat', 'Dog', 'Bird']}
pets_df = pd.DataFrame(data)

# %% [markdown]
# ### value_counts()

# %%
print(pets_df['Type'].value_counts())
# Out:
# Type
# Dog     3
# Cat     2
# Bird    1
# Name: count, dtype: int64

# %% [markdown]
# ### Grouping and Aggregating with `groupby()` and `agg()` methods

# %%
import pandas as pd

# Creating DataFrame
data =  {'Name': ['Tommy', 'Rex', 'Bella', 'Charlie', 'Lucy', 'Cooper'],
         'Type': ['Dog', 'Dog', 'Cat', 'Cat', 'Dog', 'Bird'],
         'Weight': [12, 15, 8, 9, 14, 1]}
pets_df = pd.DataFrame(data)

print(pets_df.groupby('Type').agg({'Weight': 'mean'}))
# Out:
#          Weight
# Type
# Bird   1.000000
# Cat    8.500000
# Dog   13.666667

# %% [markdown]
# ### Sorting DataFrame with `sort_values()`

# %%
sorted_pets_df = pets_df.sort_values('Weight')
print(sorted_pets_df)
# Out:
#       Name  Type  Weight
# 5   Cooper  Bird       1
# 2    Bella   Cat       8
# 3  Charlie   Cat       9
# 0    Tommy   Dog      12
# 4     Lucy   Dog      14
# 1      Rex   Dog      15

# %%
import pandas as pd

# Dictionary of pet care records
pet_care_data = {
    'PetID': [101, 102, 103, 104, 105],
    'Specie': ['Dog', 'Cat', 'Bird', 'Dog', 'Cat'],
    'Visits': [2, 3, 1, 4, 2]
}

# Create DataFrame from dictionary
pet_care_df = pd.DataFrame(pet_care_data)

# Calculate the median number of visits by species
median_visits_by_specie = pet_care_df.groupby('Specie').agg({'Visits': 'median'})
print(median_visits_by_specie)
# Out:
#         Visits
# Specie
# Bird       1.0
# Cat        2.5
# Dog        3.0

# %%
import pandas as pd

# Creating the DataFrame
pets_df = pd.DataFrame({
    'Name': ['Buddy', 'Max', 'Luna', 'Bella', 'Leo'],
    'Type': ['Cat', 'Dog', 'Dog', 'Bird', 'Cat'],
    'Height': [25, 40, 35, 15, 20]
})

# TODO: sort pets_df by the 'Type' column in descending order.
sorted_pets_df = pets_df.sort_values('Type', ascending=False)
print(sorted_pets_df)
# Out:
#     Name  Type  Height
# 1    Max   Dog      40
# 2   Luna   Dog      35
# 0  Buddy   Cat      25
# 4    Leo   Cat      20
# 3  Bella  Bird      15

# %%
import pandas as pd

# Dataset for pet care management
pet_care = {'PetID': [101, 102, 103, 104, 105],
             'Type': ['Dog', 'Cat', 'Bird', 'Dog', 'Cat'],
             'Visits': [2, 3, 1, 5, 2]}

pets_df = pd.DataFrame(pet_care)
# TODO: group the data by Type
pet=pets_df.groupby('Type').agg({'Visits':'sum'})
print(pet)
# TODO: aggregate by the sum of visits
# Out:
#       Visits
# Type
# Bird       1
# Cat        5
# Dog        7

# %%
import pandas as pd

# Pet Care DataFrame
pets_df = pd.DataFrame({
    'PetType': ['Dog', 'Cat', 'Dog', 'Bird', 'Dog', 'Cat'],
    'PetName': ['Buddy', 'Whiskers', 'Duke', 'Tweety', 'Max', 'Ginger']
})

# TODO: Find out how many of each type of pet we have
print(pets_df['PetType'].value_counts())
# Out:
# PetType
# Dog     3
# Cat     2
# Bird    1
# Name: count, dtype: int64
