# %% [markdown]
# # Plot Customization with Colors

# %% [markdown]
# ## Adding Colors in Matplotlib

# %% [markdown]
# Here are the primary options for specifying colors:
#
# Named Colors: Use predefined color names such as 'blue', 'skyblue', or 'tomato'.
#
# Hexadecimal Codes: Specify colors using hex codes, e.g., '#1f77b4'.
#
# RGB Tuples: Define colors using RGB values as a tuple, such as (0.1, 0.2, 0.5).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
penguins=sns.load_dataset('penguins')

# %%
# Count the number of occurrences for each species
species_counts = penguins['species'].value_counts()

# Create a pie chart with multiple mixed color 
plt.pie(species_counts, labels=species_counts.index, colors=['gold', "#5D4848", (0.5, 0.8, 0.9)])

# Display the pie chart
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

# TODO: Define the color of the line plot as 'green'
plt.figure(figsize=(8, 4))
plt.plot(penguins['flipper_length_mm'],color='green', label='Flipper Length')
plt.title('Line Plot with Color')
plt.xlabel('Sample Number')
plt.ylabel('Flipper Length (mm)')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')


plt.figure(figsize=(10, 6))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'], color='#808080')
plt.title('Hexadecimal Colored Scatter Plot')
plt.xlabel('Penguin Bill Length (mm)')
plt.ylabel('Penguin Body Mass (g)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')


plt.figure(figsize=(8, 4))
plt.hist(penguins['bill_depth_mm'], color=(0.1, 0.39, 1.0))
plt.title('Histogram with Modified Color to Orange')
plt.xlabel('Bill Depth (mm)')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

# Count the number of occurrences for each species
species_counts = penguins['species'].value_counts()

# TODO: Add colors for the pie chart segments using the named colors 'coral', 'chartreuse', and 'gray'
plt.figure(figsize=(5, 5))
plt.pie(species_counts, labels=species_counts.index,colors=['coral', 'chartreuse','gray'])
plt.title('Pie Chart with Updated Colors')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

# Count the number of occurrences for each species
species_counts = penguins['species'].value_counts()

# TODO: Add colors to each bar using a named color, a hex color, and an RGB tuple respectively
plt.figure(figsize=(8, 4))
plt.bar(species_counts.index, species_counts,color=('cyan','#FF00FF',(1.0, 0.5, 0.5)))
plt.title('Bar Chart with Color')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Improving Data Visualization with Grids

# %% [markdown]
# ### Adding a Basic Grid in Matplotlib

# %%
# Load the dataset
penguins = sns.load_dataset('penguins')

# Scatter plot of Bill Length vs. Body Mass
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Basic Grid')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')

# Add a basic grid with default settings
plt.grid(True)

# Display the plot
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Basic Grid')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')

# Add a grid with a customized color
plt.grid(True, color='green')

# Display the plot
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Basic Grid')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')
plt.grid(True, linestyle='--')
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Basic Grid')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')
plt.grid(True,linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Basic Grid')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')
# Add a grid with customized color, linestyle, and linewidth
plt.grid(True, color='green', linestyle='--', linewidth=0.5)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

# Scatter plot of Bill Length vs. Body Mass
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Basic Grid')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')

# TODO: Add a basic grid to the plot
plt.grid(True)
# Display scatter plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

# Scatter plot of Bill Length vs. Body Mass
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Customized Grid')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')

# TODO: Change the color of the grid to green
plt.grid(True,color='green')

# Display scatter plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

# Scatter plot of Bill Length vs. Body Mass
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Customized Grid')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')

# TODO: Change the grid line style to dashed ('--')
plt.grid(True, color='green',linestyle='--')

# Display scatter plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

# Scatter plot of Bill Length vs. Body Mass
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Customized Grid')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')

# TODO: Change width of the grid lines to 0.5
plt.grid(True, color='green', linestyle='--',linewidth=0.5)

# Display scatter plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

# Scatter plot of Bill Length vs. Body Mass
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Customized Grid')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')

# TODO: Set up grid with:
# - Color: red 
# - Line Style: Dashed-dot '-.'
# - Line Width: 1.0
plt.grid(True,color='red',linestyle='-.',linewidth=1)
# Display scatter plot
plt.show()

# %% [markdown]
# ### Themes for Consistent Style

# %% [markdown]
# ### Exploring Seaborn Themes

# %% [markdown]
# "darkgrid": Adds a dark grid, giving a structured background that enhances data visibility.
#
# "whitegrid": Similar to "darkgrid", but with a lighter tone for a clean, minimalist appeal.
#
# "dark": Offers a dark background without gridlines, helping colorful data stand out.
#
# "white": Features a plain white background, keeping the focus purely on the data.
#
# "ticks": Provides a white background with axis ticks to emphasize precision and clarity.

# %%
# Load the dataset
penguins = sns.load_dataset('penguins')

# Apply a Seaborn theme
sns.set_theme(style="darkgrid")

# Themed scatter plot
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Darkgrid Theme')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


penguins = sns.load_dataset('penguins')

sns.set_theme(style="darkgrid")


plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Darkgrid Theme')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

# TODO: Change the Seaborn theme to "whitegrid"
sns.set_theme(style="whitegrid")

# Themed scatter plot
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Theme')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

# Apply a Seaborn theme
sns.set_theme(style="darkgrid")

# Themed scatter plot
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Darkgrid Theme')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
penguins = sns.load_dataset('penguins')

sns.set_theme(style='dark')
# Themed scatter plot
plt.figure(figsize=(8, 4))
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.title('Scatter Plot with Dark Theme')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Body Mass (g)')
plt.show()
