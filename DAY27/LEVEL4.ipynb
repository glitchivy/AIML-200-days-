# %% [markdown]
# plt.bar()       → compare categories
#
# plt.barh()      → horizontal category comparison
#
# plt.hist()      → numerical distribution
#
# plt.scatter()   → relationship between variables
#
# plt.pie()       → part of a whole
#
# plt.boxplot()   → spread + median + outliers
#
# plt.stem()      → discrete individual values

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Question 31 — Basic Bar Chart
#
# ### Task
#
# Create a vertical bar chart showing the number of employees in each department.
#
# ### Data
#
# ```python
# departments = ["HR", "IT", "Sales", "Finance", "Marketing"]
# employees = [25, 60, 80, 40, 55]

# %%
departments = ["HR", "IT", "Sales", "Finance", "Marketing"]
employees = [25, 60, 80, 40, 55]
plt.bar(departments,employees)
plt.show()

# %% [markdown]
# # Question 32 — Horizontal Bar Chart
#
# ### Task
#
# Create a horizontal bar chart showing employees in each department.
#
# ### Data
#
# ```python
# departments = ["HR", "IT", "Sales", "Finance", "Marketing"]
# employees = [25, 60, 80, 40, 55]

# %%
departments = ["HR", "IT", "Sales", "Finance", "Marketing"]
employees = [25, 60, 80, 40, 55]
plt.title("employee departments")
plt.barh(departments,employees)
plt.xlabel("employee count")
plt.ylabel("Department")
plt.show()

# %% [markdown]
# # Question 33 — Histogram
#
# ### Task
#
# Create a histogram showing the distribution of employee ages.
#
# ### Data
#
# ```python
# ages = [
#     22, 25, 28, 30, 31, 32, 35, 36, 38, 40,
#     41, 42, 43, 45, 46, 47, 48, 50, 52, 55
# ]

# %%
ages = [
    22, 25, 28, 30, 31, 32, 35, 36, 38, 40,
    41, 42, 43, 45, 46, 47, 48, 50, 52, 55
]
plt.hist(ages,bins=10,edgecolor='black')
plt.title("Histogram")
plt.xlabel("ages range")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# # Question 34 — Scatter Plot
#
# ### Task
#
# Create a scatter plot showing the relationship between **hours studied** and **exam scores**.
#
# ### Data
#
# ```python
# hours = [1, 2, 3, 4, 5, 6, 7, 8]
# scores = [45, 50, 55, 60, 68, 72, 80, 88]

# %%
hours = [1, 2, 3, 4, 5, 6, 7, 8]
scores = [45, 50, 55, 60, 68, 72, 80, 88]
plt.scatter(hours,scores)
plt.title("hours studied VS marks scored")
plt.xlabel("hours")
plt.ylabel("scores")
plt.show()

# %% [markdown]
# # Question 35 — Pie Chart
#
# ### Task
#
# Create a pie chart showing the **distribution of employees across departments**.
#
# ### Data
#
# ```python
# departments = ["HR", "IT", "Sales", "Finance"]
# employees = [20, 45, 60, 30]

# %%
import matplotlib.pyplot as plt
departments = ["HR", "IT", "Sales", "Finance"]
employees = [20, 45, 60, 30]
plt.title("employee distribution")
plt.pie(employees,labels=departments,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # Question 36 — Box Plot
#
# ### Task
#
# Create a box plot showing the distribution of employee salaries.
#
# ### Data
#
# ```python
# salaries = [
#     25000, 28000, 30000, 32000, 35000,
#     36000, 38000, 40000, 42000, 45000,
#     48000, 50000, 55000, 60000, 75000
# ]

# %%
salaries = [
    25000, 28000, 30000, 32000, 35000,
    36000, 38000, 40000, 42000, 45000,
    48000, 50000, 55000, 60000, 75000
]
plt.boxplot(salaries)
plt.title("the box plot of salaries")
plt.show()

# %% [markdown]
# # Question 37 — Stem Plot
#
# ### Task
#
# Create a stem plot showing the growth of a value over time.
#
# ### Data
#
# ```python
# x = [1, 2, 3, 4, 5, 6]
# y = [10, 15, 13, 20, 25, 30]

# %%
x = [1, 2, 3, 4, 5, 6]
y = [10, 15, 13, 20, 25, 30]

plt.stem(x, y)
plt.title("Value Growth")
plt.xlabel("Time")
plt.ylabel("Value")

plt.show()

# %% [markdown]
# # Question 38 — Area Chart
#
# ### Task
#
# Create an area chart showing sales growth over time.
#
# ### Data
#
# ```python
# x = [1, 2, 3, 4, 5, 6]
#
# sales = [20, 30, 25, 40, 50, 60]

# %% [markdown]
# plt.plot()         → draws the line
#
# plt.fill_between() → fills the area underneath

# %%
x = [1, 2, 3, 4, 5, 6]

sales = [20, 30, 25, 40, 50, 60]
plt.plot(x,sales)
plt.fill_between(x,sales)
plt.show()

# %% [markdown]
# # Question 39 — Error Bar Plot
#
# ### Task
#
# Create an error bar plot showing measurements with uncertainty.
#
# ### Data
#
# ```python
# x = [1, 2, 3, 4, 5]
#
# y = [20, 25, 30, 28, 35]
#
# error = [2, 3, 2, 4, 3]

# %%
x = [1, 2, 3, 4, 5]

y = [20, 25, 30, 28, 35]

error = [2, 3, 2, 4, 3]

plt.errorbar(x,y,error)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Question 40 — Step Plot
#
# ### Task
#
# Create a step plot showing how a value changes over time.
#
# ### Data
#
# ```python
# x = [1, 2, 3, 4, 5, 6]
#
# y = [10, 10, 20, 20, 30, 30]

# %%
x = [1, 2, 3, 4, 5, 6]

y = [10, 10, 20, 20, 30, 30]
plt.step(x,y)

plt.title("Value Changes Over Time")
plt.xlabel("Time")
plt.ylabel("Value")

plt.show()
