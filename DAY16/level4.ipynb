# %% [markdown]
# # Level 4: Sorting & Manipulation (56–65)

# %%
import pandas as pd

df = pd.DataFrame({
    "ID": [101,102,103,104,105,106,107,108],
    "Name": ["Alice","Bob","Charlie","David","Eva","Frank","Grace","Helen"],
    "Department": ["HR","IT","IT","Finance","HR","Finance","IT","Marketing"],
    "Age": [25,30,22,35,28,40,29,27],
    "Salary": [45000,60000,55000,80000,48000,90000,62000,50000],
    "City": ["Mumbai","Delhi","Pune","Mumbai","Delhi","Pune","Mumbai","Delhi"]
})

# %% [markdown]
# # Pandas Level 4 - Question 56
#
# ## Topic
# **Sort by One Column (`sort_values`)**
#
# ---
#
# ## Problem Statement
#
# Using the existing DataFrame (`df`), sort the DataFrame by the **Salary** column in **ascending order**.
#
# Store the sorted DataFrame in a variable named `result` and print it.
